# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score

#!pip install tensorflow==2.11.0

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Conv1D,Dense, GlobalAveragePooling1D, Embedding, MultiHeadAttention
from tensorflow.keras.layers import MaxPool1D, Dropout, LayerNormalization, MaxPooling1D, Input
from tensorflow.keras.models import Sequential, Model

from sklearn.metrics import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix

gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for device in gpu_devices:
    tf.config.experimental.set_memory_growth(device, True)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
weight_address = '/content/drive/MyDrive/old_code/weights/'
results_address = '/content/drive/MyDrive/old_code/results/'
NUM_CLASSES = 10

# %% [markdown]
# ### The networks

# %% [markdown]
# #### Transformer

# %%
class TokenAndPositionEmbedding(tf.keras.layers.Layer):
    def __init__(self, maxlen, vocab_size, embed_dim):
        super(TokenAndPositionEmbedding, self).__init__()
        self.embed_dim = embed_dim
        self.token_emb = Embedding(input_dim= vocab_size, output_dim= embed_dim)
        self.maxlen = maxlen

    def get_angles(self, pos, i, embd_dim):
        angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(embd_dim))
        return pos * angle_rates

    def positional_encoding(self, max_pos_enc, embd_dim):
        angle_rads = self.get_angles(np.arange(max_pos_enc)[:, np.newaxis],
                                np.arange(embd_dim)[np.newaxis, :],
                                embd_dim)

        # apply sin to even indices in the array; 2i
        angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])

        # apply cos to odd indices in the array; 2i+1
        angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])

        pos_encoding = angle_rads[np.newaxis, ...]

        return tf.cast(pos_encoding, dtype=tf.float32)

    def call(self, x):
        positions = self.positional_encoding(max_pos_enc= self.maxlen, embd_dim= self.embed_dim)
        x = self.token_emb(x)
        return x + positions

# %%
class TransformerBlock(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.att = MultiHeadAttention(num_heads= num_heads, key_dim= embed_dim)
        self.ffn = tf.keras.Sequential(
            [Dense(ff_dim, activation="relu"), Dense(embed_dim),]
        )
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        self.dropout1 = Dropout(rate)
        self.dropout2 = Dropout(rate)

    def call(self, inputs, training):
        attn_output = self.att(inputs, inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

# %% [markdown]
# ### Transformer and CNN

# %%
@tf.autograph.experimental.do_not_convert # added to silence a warning related to TF
def create_model_cnn_transformer(maxlen = 29964, vocab_size = 33983,
                                embed_dim = 50, num_heads = 2,
                                ff_dim = 16, dout = 0.1,
                                filters = 64, kernel_size = 3,
                                pool_window = 2, extra_dense_nodes = 20, pool = 'maxpool',
                                summary = True):
    '''
    embed_dim - Embedding size for each token
    num_heads - Number of attention heads
    ff_dim - Hidden layer size in feed forward network inside transformer
    pool - can be "maxpool" for local maxpooling or "globalAvg" for global average pooling
    '''
    # input
    inputs = Input(shape=(maxlen,))
    # embeddding
    embedding_layer = TokenAndPositionEmbedding(inputs.shape[1], vocab_size, embed_dim)
    x = embedding_layer(inputs)
    # convolution
    x = Conv1D(filters= filters, kernel_size= kernel_size)(x)
    if pool == 'maxpool':
        x = MaxPooling1D(pool_size= pool_window)(x)
    else:
        print('the feature not working yet')

    print(x.shape)
    # transformer
    transformer_block = TransformerBlock(filters, num_heads, ff_dim)
    # print('transformer_block input shape:', x.shape)
    x = transformer_block(x)
    # extra dense layers
    x = GlobalAveragePooling1D()(x)
    x = Dropout(dout)(x)
    if extra_dense_nodes!= 0:
        x = Dense(extra_dense_nodes, activation= "relu")(x)
        x = Dropout(dout)(x)
    # output
    outputs = Dense(NUM_CLASSES, activation= "softmax")(x)

    model= Model(inputs=inputs, outputs= outputs)
    if summary:
        model.summary()

    return model

# %% [markdown]
# ### CNN

# %%
def create_CNN_model(layers = 2, filters = [32, 64, 128], kernel_size= 3,
                      embed_dim = 50, vocab_size = 33982, summary= False):

    model = Sequential()
    model.add(Embedding(vocab_size+1, embed_dim))#, input_length = X_train_padded.shape[1]))

    for i in range(layers):
        model.add(Conv1D(filters = filters[i], kernel_size = kernel_size, activation='relu'))
        model.add(MaxPool1D(pool_size = 2, strides=2))

    model.add(GlobalAveragePooling1D())
    model.add(Dense(NUM_CLASSES, activation= 'softmax'))
    if summary:
        model.summary()
    return model

# %% [markdown]
# ### Kmer method

# %% [markdown]
# #### Loading the saved data

# %%
with open('/content/drive/MyDrive/old_code/X_train_k7.pkl', 'rb') as f:
    X_train = pickle.load(f)
with open('/content/drive/MyDrive/old_code/Y_train_k7.pkl', 'rb') as f:
    Y_train = pickle.load(f)

X_train.shape, Y_train
# Out:
# ((4000, 29964),
#  4227    8
#  4676    9
#  800     1
#  3671    7
#  4193    8
#         ..
#  4426    8
#  466     0
#  3092    6
#  3772    7
#  860     1
#  Name: label, Length: 4000, dtype: int64)

# %%
with open('/content/drive/MyDrive/old_code/X_test_list_k3.pkl', 'rb') as f:
    X_test = pickle.load(f)
with open('/content/drive/MyDrive/old_code/Y_test_list_k3.pkl', 'rb') as f:
    Y_test = pickle.load(f)

X_test.shape, Y_test
# Out:
# ((1000, 29964),
#  array([3, 5, 5, 2, 1, 0, 1, 4, 4, 3, 4, 0, 1, 1, 6, 7, 2, 6, 3, 2, 1, 6,
#         2, 1, 9, 1, 8, 0, 9, 0, 3, 0, 9, 9, 3, 5, 7, 8, 9, 4, 7, 8, 0, 0,
#         1, 7, 7, 9, 6, 5, 9, 9, 4, 5, 2, 6, 2, 0, 3, 5, 4, 8, 8, 7, 0, 5,
#         6, 4, 7, 9, 3, 0, 0, 0, 2, 4, 1, 5, 5, 7, 6, 6, 8, 3, 6, 2, 1, 1,
#         9, 7, 8, 0, 0, 2, 0, 9, 5, 6, 0, 0, 3, 3, 4, 8, 0, 0, 1, 2, 9, 2,
#         2, 2, 8, 1, 4, 7, 4, 4, 0, 4, 2, 2, 9, 0, 4, 9, 4, 9, 5, 6, 8, 6,
#         3, 2, 7, 8, 8, 7, 1, 0, 7, 7, 9, 7, 8, 6, 5, 7, 5, 5, 2, 7, 9, 9,
#         3, 0, 5, 5, 7, 0, 4, 6, 1, 2, 0, 7, 2, 3, 6, 4, 6, 3, 5, 6, 0, 6,
#         8, 6, 0, 3, 9, 5, 3, 0, 5, 7, 7, 7, 1, 3, 1, 7, 7, 9, 4, 2, 1, 5,
#         7, 8, 7, 1, 5, 8, 6, 4, 4, 6, 7, 1, 6, 1, 7, 4, 8, 4, 9, 0, 7, 2,
#         3, 1, 9, 6, 3, 6, 5, 5, 0, 4, 1, 7, 2, 9, 0, 6, 6, 1, 5, 9, 1, 1,
#         8, 8, 2, 3, 4, 2, 3, 9, 9, 8, 3, 2, 4, 1, 7, 4, 0, 1, 3, 4, 4, 8,
#         2, 3, 4, 5, 5, 0, 1, 2, 9, 0, 3, 6, 2, 5, 7, 2, 9, 9, 1, 2, 3, 7,
#         2, 6, 3, 1, 0, 5, 4, 4, 6, 1, 4, 4, 8, 2, 0, 0, 6, 2, 5, 9, 9, 5,
#         0, 3, 6, 7, 4, 9, 3, 1, 3, 5, 9, 7, 9, 7, 4, 6, 0, 1, 4, 1, 8, 8,
#         7, 0, 8, 2, 0, 1, 1, 1, 7, 2, 8, 8, 2, 4, 7, 7, 9, 6, 4, 4, 6, 7,
#         2, 0, 9, 0, 6, 0, 2, 3, 0, 0, 7, 4, 1, 6, 0, 0, 1, 8, 7, 7, 3, 4,
#         4, 8, 6, 0, 2, 8, 7, 8, 5, 4, 2, 3, 9, 0, 2, 4, 3, 9, 6, 0, 1, 5,
#         3, 3, 7, 6, 2, 8, 1, 5, 7, 4, 3, 1, 0, 5, 2, 6, 5, 2, 0, 8, 0, 9,
#         6, 5, 5, 5, 4, 2, 4, 9, 1, 2, 9, 1, 1, 8, 3, 5, 4, 5, 4, 7, 0, 5,
#         7, 0, 5, 3, 3, 3, 4, 9, 0, 0, 5, 6, 8, 2, 9, 2, 4, 5, 7, 1, 2, 1,
#         2, 6, 5, 7, 5, 9, 9, 9, 5, 5, 1, 5, 5, 5, 5, 3, 1, 0, 8, 7, 3, 6,
#         7, 9, 0, 6, 0, 1, 0, 2, 1, 5, 1, 7, 1, 0, 3, 7, 7, 7, 0, 8, 2, 0,
#         2, 1, 3, 4, 7, 5, 3, 1, 0, 2, 4, 0, 0, 8, 8, 7, 2, 5, 4, 0, 8, 6,
#         7, 9, 5, 2, 7, 0, 7, 7, 1, 7, 5, 9, 3, 5, 3, 9, 8, 6, 7, 8, 7, 1,
#         6, 4, 7, 1, 4, 2, 9, 9, 9, 6, 8, 6, 6, 4, 2, 9, 7, 3, 5, 7, 9, 7,
#         7, 4, 0, 9, 2, 8, 6, 7, 2, 9, 2, 7, 2, 6, 9, 4, 1, 9, 7, 2, 4, 9,
#         9, 2, 6, 4, 2, 3, 1, 8, 2, 9, 9, 7, 1, 5, 8, 9, 0, 9, 3, 0, 8, 4,
#         2, 1, 0, 2, 3, 6, 1, 6, 8, 9, 3, 2, 3, 0, 2, 1, 0, 6, 4, 1, 2, 8,
#         9, 7, 6, 6, 5, 4, 8, 7, 6, 8, 1, 8, 7, 1, 9, 5, 1, 4, 7, 1, 2, 2,
#         2, 0, 7, 2, 4, 5, 1, 6, 7, 0, 7, 0, 2, 1, 3, 6, 6, 2, 8, 6, 5, 1,
#         2, 7, 8, 8, 0, 4, 8, 9, 8, 9, 0, 4, 3, 4, 0, 2, 4, 1, 9, 8, 6, 5,
#         9, 9, 4, 0, 7, 7, 8, 3, 0, 8, 6, 3, 7, 1, 2, 6, 7, 2, 1, 7, 5, 9,
#         1, 1, 5, 5, 9, 1, 7, 2, 9, 9, 0, 1, 6, 0, 5, 1, 7, 8, 9, 5, 1, 1,
#         1, 9, 4, 6, 9, 9, 7, 0, 4, 5, 8, 6, 7, 2, 3, 6, 8, 1, 2, 5, 5, 3,
#         4, 2, 3, 0, 7, 7, 1, 0, 2, 7, 5, 4, 8, 5, 8, 5, 7, 2, 6, 2, 5, 3,
#         9, 0, 9, 3, 0, 6, 9, 2, 5, 3, 4, 2, 4, 7, 6, 9, 0, 9, 1, 3, 2, 3,
#         6, 6, 4, 7, 9, 4, 1, 9, 6, 9, 5, 2, 1, 2, 7, 7, 8, 3, 0, 9, 6, 5,
#         9, 1, 5, 5, 9, 0, 3, 1, 0, 9, 4, 8, 9, 8, 3, 0, 2, 7, 5, 0, 2, 0,
#         8, 5, 6, 6, 5, 9, 7, 5, 1, 5, 4, 9, 4, 1, 0, 8, 6, 5, 6, 2, 3, 2,
#         3, 2, 4, 6, 1, 3, 9, 7, 1, 8, 6, 9, 6, 5, 8, 6, 4, 6, 6, 6, 1, 6,
#         8, 5, 9, 1, 5, 0, 6, 8, 1, 3, 4, 4, 7, 4, 7, 8, 8, 0, 9, 3, 2, 1,
#         9, 7, 7, 9, 1, 2, 0, 8, 3, 1, 4, 0, 8, 6, 0, 9, 5, 8, 9, 3, 3, 3,
#         3, 4, 0, 4, 6, 9, 1, 7, 1, 0, 2, 4, 9, 5, 3, 2, 7, 3, 7, 9, 0, 2,
#         4, 5, 3, 0, 0, 2, 5, 6, 6, 3, 7, 7, 1, 0, 9, 6, 6, 3, 5, 0, 9, 9,
#         1, 2, 8, 4, 8, 9, 4, 6, 5, 3]))

# %% [markdown]
# #### Training helpers

# %%
model_names = ['transformer_cnn_k3_32f_4pool',
            'transformer_cnn_k3_64f_4pool',
            'transformer_cnn_k3_128f_4pool',
            'cnn_k3_2layers']

# %%
lr_decay = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=5,
    verbose= 1
    )

es = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    verbose=1,
    patience=5,
    mode="auto",
    restore_best_weights=True,
)

adam_opt = tf.keras.optimizers.Adam(learning_rate=0.001)

# %%
def evaluate_model(model, model_name):
    model.load_weights(weight_address+model_name) # loads the best weight before evaluating
    print('Test F1 score:')
    preds = np.argmax(model.predict(X_test, batch_size=8), axis = 1)
    score = f1_score(Y_test, preds, average = 'weighted')
    print(score)

# %%
def plot_history(history, model_name):
    print('Highest train acc: {:.3f} epoch: {}\nHighest val acc: {:.3f} epoch: {}'\
        .format(max(history.history['accuracy']), 1+np.argmax(np.array(history.history['accuracy'])),
                max(history.history['val_accuracy']), 1+np.argmax(np.array(history.history['val_accuracy']))))

    plt.title('Training history of '+ model_name)
    plt.plot(history.history['accuracy'],'ro-')
    plt.plot(history.history['val_accuracy'],'bx-')
    plt.legend(['accuracy','val_accuracy'])
    plt.savefig(results_address+model_name+'.png')
    plt.show()

# %%
def make_checkpointer(model_name):
    return tf.keras.callbacks.ModelCheckpoint(
    weight_address+model_name, monitor='val_loss', verbose=0, save_best_only=True,
    save_weights_only=True)

# %%
metrics = ['accuracy']

# %% [markdown]
# #### Training

# %% [markdown]
# data with pool size smaller than 4 does not fit in my GPU

# %%
eps = 20

# %%
model_name = model_names[0]
print(model_name)

check_point = make_checkpointer(model_name)
model = create_model_cnn_transformer(filters=32, pool_window=4)

model.compile(optimizer=adam_opt, loss= "sparse_categorical_crossentropy", metrics= metrics)

history = model.fit(X_train, Y_train,
                    batch_size=8, epochs=eps,
                    validation_data=(X_test, Y_test),
                    callbacks = [check_point, lr_decay])

plot_history(history, model_name)
evaluate_model(model, model_name)
# Out:
# transformer_cnn_k3_32f_4pool
# (None, 7490, 32)
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 29964)]           0
#
#  token_and_position_embeddin  (None, 29964, 50)        1699150
#  g_1 (TokenAndPositionEmbedd
#  ing)
#
#  conv1d_1 (Conv1D)           (None, 29962, 32)         4832
#
#  max_pooling1d_1 (MaxPooling  (None, 7490, 32)         0
#  1D)
#
#  transformer_block_1 (Transf  (None, 7490, 32)         9616
#  ormerBlock)
#
#  global_average_pooling1d_1   (None, 32)               0
#  (GlobalAveragePooling1D)
#
#  dropout_6 (Dropout)         (None, 32)                0
#
#  dense_6 (Dense)             (None, 20)                660
#
#  dropout_7 (Dropout)         (None, 20)                0
#
#  dense_7 (Dense)             (None, 10)                210
#
# =================================================================
# Total params: 1,714,468
# Trainable params: 1,714,468
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 500/500 [==============================] - 322s 635ms/step - loss: 2.3085 - accuracy: 0.1030 - val_loss: 2.3034 - val_accuracy: 0.0980 - lr: 0.0010
# Epoch 2/20
# 500/500 [==============================] - 290s 580ms/step - loss: 2.3039 - accuracy: 0.1095 - val_loss: 2.3019 - val_accuracy: 0.1000 - lr: 0.0010
# Epoch 3/20
# 500/500 [==============================] - 284s 568ms/step - loss: 2.2896 - accuracy: 0.1338 - val_loss: 2.2606 - val_accuracy: 0.1990 - lr: 0.0010
# Epoch 4/20
# 500/500 [==============================] - 282s 563ms/step - loss: 1.3814 - accuracy: 0.4865 - val_loss: 0.4800 - val_accuracy: 0.8770 - lr: 0.0010
# Epoch 5/20
# 500/500 [==============================] - 280s 561ms/step - loss: 0.2135 - accuracy: 0.9413 - val_loss: 0.0600 - val_accuracy: 0.9840 - lr: 0.0010
# Epoch 6/20
# 500/500 [==============================] - 278s 556ms/step - loss: 0.0658 - accuracy: 0.9847 - val_loss: 0.0368 - val_accuracy: 0.9900 - lr: 0.0010
# Epoch 7/20
# 500/500 [==============================] - 278s 556ms/step - loss: 0.0329 - accuracy: 0.9927 - val_loss: 0.0247 - val_accuracy: 0.9950 - lr: 0.0010
# Epoch 8/20
# 500/500 [==============================] - 276s 552ms/step - loss: 0.0288 - accuracy: 0.9918 - val_loss: 0.0356 - val_accuracy: 0.9920 - lr: 0.0010
# Epoch 9/20
# 500/500 [==============================] - 275s 549ms/step - loss: 0.0197 - accuracy: 0.9942 - val_loss: 0.0386 - val_accuracy: 0.9920 - lr: 0.0010
# Epoch 10/20
# 500/500 [==============================] - 275s 550ms/step - loss: 0.0137 - accuracy: 0.9955 - val_loss: 0.0263 - val_accuracy: 0.9960 - lr: 0.0010
# Epoch 11/20
# 500/500 [==============================] - 274s 548ms/step - loss: 0.0060 - accuracy: 0.9990 - val_loss: 0.0256 - val_accuracy: 0.9940 - lr: 0.0010
# Epoch 12/20
# 500/500 [==============================] - 274s 548ms/step - loss: 0.0059 - accuracy: 0.9983 - val_loss: 0.0236 - val_accuracy: 0.9960 - lr: 0.0010
# Epoch 13/20
# 500/500 [==============================] - 274s 547ms/step - loss: 0.0170 - accuracy: 0.9945 - val_loss: 0.0295 - val_accuracy: 0.9930 - lr: 0.0010
# Epoch 14/20
# 500/500 [==============================] - 272s 545ms/step - loss: 0.0144 - accuracy: 0.9952 - val_loss: 0.0245 - val_accuracy: 0.9930 - lr: 0.0010
# Epoch 15/20
# 500/500 [==============================] - 271s 543ms/step - loss: 0.0042 - accuracy: 0.9992 - val_loss: 0.0227 - val_accuracy: 0.9940 - lr: 0.0010
# Epoch 16/20
# 500/500 [==============================] - 271s 542ms/step - loss: 0.0062 - accuracy: 0.9983 - val_loss: 0.0218 - val_accuracy: 0.9940 - lr: 0.0010
# Epoch 17/20
# 500/500 [==============================] - 271s 542ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.0143 - val_accuracy: 0.9950 - lr: 0.0010
# Epoch 18/20
# 500/500 [==============================] - 270s 540ms/step - loss: 0.0070 - accuracy: 0.9973 - val_loss: 0.0205 - val_accuracy: 0.9950 - lr: 0.0010
# Epoch 19/20
# 500/500 [==============================] - 269s 538ms/step - loss: 0.0176 - accuracy: 0.9948 - val_loss: 0.0287 - val_accuracy: 0.9940 - lr: 0.0010
# Epoch 20/20
# 500/500 [==============================] - 270s 540ms/step - loss: 0.0099 - accuracy: 0.9965 - val_loss: 0.0115 - val_accuracy: 0.9970 - lr: 0.0010
# Highest train acc: 0.999 epoch: 17
# Highest val acc: 0.997 epoch: 20
# Test F1 score:
# 125/125 [==============================] - 26s 203ms/step
# 0.9970008208667335

# %%
predictions = model.predict(X_test, batch_size = 8)
predictions = np.argmax(predictions, axis = -1)
labels = Y_test

cm  = confusion_matrix(labels, predictions)
plot_confusion_matrix(cm,figsize=(4,4), hide_ticks=True, cmap=plt.cm.Blues)
plt.xticks(range(NUM_CLASSES), [i+1 for i in range(NUM_CLASSES)], fontsize=12)
plt.yticks(range(NUM_CLASSES), [i+1 for i in range(NUM_CLASSES)], fontsize=12)
plt.show()

# %%
eps = 40

# %%
model_name = model_names[1]
print(model_name)
check_point = make_checkpointer(model_name)

model = create_model_cnn_transformer(filters=64, pool_window=4)

model.compile(optimizer= adam_opt, loss= "sparse_categorical_crossentropy", metrics=metrics)

history = model.fit(X_train, Y_train,
                    batch_size=8, epochs=eps,
                    validation_data=(X_test, Y_test),
                    callbacks = [check_point, lr_decay])

plot_history(history, model_name)
evaluate_model(model, model_name)
# Out:
# transformer_cnn_k3_64f_4pool
# (None, 7490, 64)
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 29964)]           0
#
#  token_and_position_embeddin  (None, 29964, 50)        1699150
#  g (TokenAndPositionEmbeddin
#  g)
#
#  conv1d (Conv1D)             (None, 29962, 64)         9664
#
#  max_pooling1d (MaxPooling1D  (None, 7490, 64)         0
#  )
#
#  transformer_block (Transfor  (None, 7490, 64)         35600
#  merBlock)
#
#  global_average_pooling1d (G  (None, 64)               0
#  lobalAveragePooling1D)
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 20)                1300
#
#  dropout_3 (Dropout)         (None, 20)                0
#
#  dense_3 (Dense)             (None, 10)                210
#
# =================================================================
# Total params: 1,745,924
# Trainable params: 1,745,924
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 500/500 [==============================] - 369s 724ms/step - loss: 2.3042 - accuracy: 0.1020 - val_loss: 2.3037 - val_accuracy: 0.0850 - lr: 0.0010
# Epoch 2/40
# 500/500 [==============================] - 337s 673ms/step - loss: 2.3032 - accuracy: 0.1002 - val_loss: 2.3045 - val_accuracy: 0.0850 - lr: 0.0010
# Epoch 3/40
# 500/500 [==============================] - 324s 647ms/step - loss: 2.3027 - accuracy: 0.1025 - val_loss: 2.3050 - val_accuracy: 0.0850 - lr: 0.0010
# Epoch 4/40
# 500/500 [==============================] - 319s 637ms/step - loss: 2.3027 - accuracy: 0.0990 - val_loss: 2.3053 - val_accuracy: 0.0810 - lr: 0.0010
# Epoch 5/40
# 500/500 [==============================] - 315s 630ms/step - loss: 2.3028 - accuracy: 0.0995 - val_loss: 2.3054 - val_accuracy: 0.0850 - lr: 0.0010
# Epoch 6/40
# 500/500 [==============================] - ETA: 0s - loss: 2.3027 - accuracy: 0.1013
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 500/500 [==============================] - 315s 630ms/step - loss: 2.3027 - accuracy: 0.1013 - val_loss: 2.3055 - val_accuracy: 0.0810 - lr: 0.0010
# Epoch 7/40
# 500/500 [==============================] - 313s 626ms/step - loss: 2.3025 - accuracy: 0.0997 - val_loss: 2.3056 - val_accuracy: 0.0810 - lr: 5.0000e-04
# Epoch 8/40
# 500/500 [==============================] - 313s 626ms/step - loss: 2.3025 - accuracy: 0.0997 - val_loss: 2.3056 - val_accuracy: 0.0810 - lr: 5.0000e-04
# Epoch 9/40
# 500/500 [==============================] - 314s 627ms/step - loss: 2.3025 - accuracy: 0.1037 - val_loss: 2.3056 - val_accuracy: 0.0810 - lr: 5.0000e-04
# Epoch 10/40
# 500/500 [==============================] - 312s 624ms/step - loss: 2.3025 - accuracy: 0.1032 - val_loss: 2.3056 - val_accuracy: 0.0810 - lr: 5.0000e-04
# Epoch 11/40
# 500/500 [==============================] - ETA: 0s - loss: 2.3033 - accuracy: 0.1010
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 500/500 [==============================] - 313s 626ms/step - loss: 2.3033 - accuracy: 0.1010 - val_loss: 2.3057 - val_accuracy: 0.0810 - lr: 5.0000e-04
# Epoch 12/40
# 500/500 [==============================] - 313s 626ms/step - loss: 2.3024 - accuracy: 0.1047 - val_loss: 2.3058 - val_accuracy: 0.0810 - lr: 2.5000e-04
# Epoch 13/40
# 500/500 [==============================] - 312s 625ms/step - loss: 2.3024 - accuracy: 0.1047 - val_loss: 2.3057 - val_accuracy: 0.0810 - lr: 2.5000e-04
# Epoch 14/40
# 500/500 [==============================] - 312s 623ms/step - loss: 2.3024 - accuracy: 0.1047 - val_loss: 2.3057 - val_accuracy: 0.0810 - lr: 2.5000e-04
# Epoch 15/40
# 500/500 [==============================] - 323s 647ms/step - loss: 2.3024 - accuracy: 0.1047 - val_loss: 2.3057 - val_accuracy: 0.0810 - lr: 2.5000e-04
# Epoch 16/40
# 500/500 [==============================] - ETA: 0s - loss: 2.3024 - accuracy: 0.1047
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 500/500 [==============================] - 313s 625ms/step - loss: 2.3024 - accuracy: 0.1047 - val_loss: 2.3057 - val_accuracy: 0.0810 - lr: 2.5000e-04
# Epoch 17/40
# 500/500 [==============================] - 312s 623ms/step - loss: 2.3023 - accuracy: 0.1047 - val_loss: 2.3057 - val_accuracy: 0.0810 - lr: 1.2500e-04
# Epoch 18/40
# 500/500 [==============================] - 312s 625ms/step - loss: 2.3023 - accuracy: 0.1047 - val_loss: 2.3057 - val_accuracy: 0.0810 - lr: 1.2500e-04
# Epoch 19/40
# 500/500 [==============================] - 312s 624ms/step - loss: 2.3023 - accuracy: 0.1047 - val_loss: 2.3057 - val_accuracy: 0.0810 - lr: 1.2500e-04
# Epoch 20/40
# 500/500 [==============================] - 312s 623ms/step - loss: 2.3023 - accuracy: 0.1047 - val_loss: 2.3056 - val_accuracy: 0.0810 - lr: 1.2500e-04
# Epoch 21/40
# 500/500 [==============================] - ETA: 0s - loss: 2.3023 - accuracy: 0.1047
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 500/500 [==============================] - 311s 623ms/step - loss: 2.3023 - accuracy: 0.1047 - val_loss: 2.3056 - val_accuracy: 0.0810 - lr: 1.2500e-04
# Epoch 22/40
# 500/500 [==============================] - 311s 623ms/step - loss: 2.3023 - accuracy: 0.1047 - val_loss: 2.3056 - val_accuracy: 0.0810 - lr: 6.2500e-05
# Epoch 23/40
# 500/500 [==============================] - 311s 623ms/step - loss: 2.3023 - accuracy: 0.1047 - val_loss: 2.3056 - val_accuracy: 0.0810 - lr: 6.2500e-05
# Epoch 24/40
# 500/500 [==============================] - 312s 623ms/step - loss: 2.3023 - accuracy: 0.1047 - val_loss: 2.3056 - val_accuracy: 0.0810 - lr: 6.2500e-05
# Epoch 25/40
# 500/500 [==============================] - 312s 624ms/step - loss: 2.3023 - accuracy: 0.1047 - val_loss: 2.3056 - val_accuracy: 0.0810 - lr: 6.2500e-05
# Epoch 26/40
# 500/500 [==============================] - ETA: 0s - loss: 2.3023 - accuracy: 0.1047
# Epoch 26: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 500/500 [==============================] - 311s 622ms/step - loss: 2.3023 - accuracy: 0.1047 - val_loss: 2.3056 - val_accuracy: 0.0810 - lr: 6.2500e-05
# Epoch 27/40
# 500/500 [==============================] - 312s 623ms/step - loss: 2.3023 - accuracy: 0.1047 - val_loss: 2.3056 - val_accuracy: 0.0810 - lr: 3.1250e-05
# Epoch 28/40
# 500/500 [==============================] - 311s 623ms/step - loss: 2.3023 - accuracy: 0.1047 - val_loss: 2.3056 - val_accuracy: 0.0810 - lr: 3.1250e-05
# Epoch 29/40
# 500/500 [==============================] - 311s 623ms/step - loss: 2.3023 - accuracy: 0.1047 - val_loss: 2.3056 - val_accuracy: 0.0810 - lr: 3.1250e-05
# Epoch 30/40
# 500/500 [==============================] - 311s 622ms/step - loss: 2.3023 - accuracy: 0.1047 - val_loss: 2.3056 - val_accuracy: 0.0810 - lr: 3.1250e-05
# Epoch 31/40
# 500/500 [==============================] - ETA: 0s - loss: 2.3023 - accuracy: 0.1047
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 500/500 [==============================] - 311s 622ms/step - loss: 2.3023 - accuracy: 0.1047 - val_loss: 2.3056 - val_accuracy: 0.0810 - lr: 3.1250e-05
# Epoch 32/40
# 500/500 [==============================] - 311s 622ms/step - loss: 2.3023 - accuracy: 0.1047 - val_loss: 2.3056 - val_accuracy: 0.0810 - lr: 1.5625e-05
# Epoch 33/40
# 500/500 [==============================] - 311s 622ms/step - loss: 2.3023 - accuracy: 0.1047 - val_loss: 2.3056 - val_accuracy: 0.0810 - lr: 1.5625e-05
# Epoch 34/40
# 500/500 [==============================] - 310s 621ms/step - loss: 2.3023 - accuracy: 0.1047 - val_loss: 2.3056 - val_accuracy: 0.0810 - lr: 1.5625e-05
# Epoch 35/40
# 500/500 [==============================] - 311s 622ms/step - loss: 2.3023 - accuracy: 0.1047 - val_loss: 2.3056 - val_accuracy: 0.0810 - lr: 1.5625e-05
# Epoch 36/40
# 500/500 [==============================] - ETA: 0s - loss: 2.3023 - accuracy: 0.1047
# Epoch 36: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 500/500 [==============================] - 311s 621ms/step - loss: 2.3023 - accuracy: 0.1047 - val_loss: 2.3056 - val_accuracy: 0.0810 - lr: 1.5625e-05
# Epoch 37/40
# 500/500 [==============================] - 311s 623ms/step - loss: 2.3023 - accuracy: 0.1047 - val_loss: 2.3056 - val_accuracy: 0.0810 - lr: 7.8125e-06
# Epoch 38/40
# 500/500 [==============================] - 311s 622ms/step - loss: 2.3023 - accuracy: 0.1047 - val_loss: 2.3056 - val_accuracy: 0.0810 - lr: 7.8125e-06
# Epoch 39/40
# 500/500 [==============================] - 311s 622ms/step - loss: 2.3023 - accuracy: 0.1047 - val_loss: 2.3056 - val_accuracy: 0.0810 - lr: 7.8125e-06
# Epoch 40/40
# 500/500 [==============================] - 311s 622ms/step - loss: 2.3023 - accuracy: 0.1047 - val_loss: 2.3056 - val_accuracy: 0.0810 - lr: 7.8125e-06
# Highest train acc: 0.105 epoch: 12
# Highest val acc: 0.085 epoch: 1
# Test F1 score:
# 125/125 [==============================] - 31s 243ms/step
# 0.013317972350230417

# %%
predictions = model.predict(X_test, batch_size = 8)
predictions = np.argmax(predictions, axis = -1)
labels = Y_test

cm  = confusion_matrix(labels, predictions)
plot_confusion_matrix(cm,figsize=(4,4), hide_ticks=True, cmap=plt.cm.Blues)
plt.xticks(range(NUM_CLASSES), [i+1 for i in range(NUM_CLASSES)], fontsize=12)
plt.yticks(range(NUM_CLASSES), [i+1 for i in range(NUM_CLASSES)], fontsize=12)
plt.show()

# %%
eps = 20

# %%
model_name = model_names[3]
print(model_name)

check_point = make_checkpointer(model_name)
model = create_CNN_model(layers=2, kernel_size=3)

model.compile(optimizer= adam_opt, loss= "sparse_categorical_crossentropy", metrics= metrics)

history = model.fit(X_train, Y_train,
                    batch_size=8, epochs=eps,
                    validation_data=(X_test, Y_test),
                    callbacks = [check_point, lr_decay])

plot_history(history, model_name)
evaluate_model(model, model_name)
# Out:
# cnn_k3_2layers
# Epoch 1/20
# 500/500 [==============================] - 80s 151ms/step - loss: 2.2977 - accuracy: 0.1147 - val_loss: 2.2847 - val_accuracy: 0.1040 - lr: 0.0010
# Epoch 2/20
# 500/500 [==============================] - 43s 85ms/step - loss: 1.6078 - accuracy: 0.5010 - val_loss: 0.5874 - val_accuracy: 0.8930 - lr: 0.0010
# Epoch 3/20
# 500/500 [==============================] - 25s 50ms/step - loss: 0.2470 - accuracy: 0.9695 - val_loss: 0.0708 - val_accuracy: 0.9990 - lr: 0.0010
# Epoch 4/20
# 500/500 [==============================] - 20s 40ms/step - loss: 0.0390 - accuracy: 0.9998 - val_loss: 0.0186 - val_accuracy: 0.9990 - lr: 0.0010
# Epoch 5/20
# 500/500 [==============================] - 18s 36ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 6/20
# 500/500 [==============================] - 17s 33ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 7/20
# 500/500 [==============================] - 16s 32ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 8/20
# 500/500 [==============================] - 15s 29ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 9/20
# 500/500 [==============================] - 14s 28ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 10/20
# 500/500 [==============================] - 14s 28ms/step - loss: 9.3233e-04 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 11/20
# 500/500 [==============================] - 14s 28ms/step - loss: 0.0174 - accuracy: 0.9958 - val_loss: 0.0022 - val_accuracy: 0.9990 - lr: 0.0010
# Epoch 12/20
# 500/500 [==============================] - 12s 24ms/step - loss: 8.3986e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 13/20
# 500/500 [==============================] - 12s 25ms/step - loss: 6.2177e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 14/20
# 500/500 [==============================] - 12s 24ms/step - loss: 5.0338e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 15/20
# 500/500 [==============================] - 12s 25ms/step - loss: 4.0828e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 16/20
# 500/500 [==============================] - 12s 23ms/step - loss: 3.3216e-04 - accuracy: 1.0000 - val_loss: 9.1471e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 17/20
# 500/500 [==============================] - 12s 23ms/step - loss: 2.7126e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 18/20
# 500/500 [==============================] - 12s 23ms/step - loss: 2.1353e-04 - accuracy: 1.0000 - val_loss: 9.5592e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 19/20
# 500/500 [==============================] - 12s 24ms/step - loss: 1.7378e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 0.9990 - lr: 0.0010
# Epoch 20/20
# 500/500 [==============================] - 11s 22ms/step - loss: 1.4179e-04 - accuracy: 1.0000 - val_loss: 7.2855e-04 - val_accuracy: 1.0000 - lr: 0.0010
# Highest train acc: 1.000 epoch: 5
# Highest val acc: 1.000 epoch: 5
# Test F1 score:
# 125/125 [==============================] - 1s 6ms/step
# 1.0

# %%
predictions = model.predict(X_test, batch_size = 8)
predictions = np.argmax(predictions, axis = -1)
labels = Y_test

cm  = confusion_matrix(labels, predictions)
plot_confusion_matrix(cm,figsize=(4,4), hide_ticks=True, cmap=plt.cm.Blues)
plt.xticks(range(NUM_CLASSES), [i+1 for i in range(NUM_CLASSES)], fontsize=12)
plt.yticks(range(NUM_CLASSES), [i+1 for i in range(NUM_CLASSES)], fontsize=12)
plt.show()
# Out:
# 125/125 [==============================] - 1s 7ms/step
